# %%
import shapefile
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import twd97
import random
import geojson
import json

# %%
geojson_file['features'].append()
# Out:
# []

# %%
df = pd.read_csv('./Data/test.csv')

# %%
df['LAT'] = df[df.columns[1]]
df['LON'] = df[df.columns[2]]
df['lat'] = df[df.columns[1]]
df['lon'] = df[df.columns[2]]

# %%
df.head()
# Out:
#      Tube ID     LAT (Y)    LON (X)        Date  IS RIFA         LAT  \
# 0   24901723  2777271.63  290155.40  2011-08-18        1  2777271.63
# 1   24900702  2779891.62  288359.56  2011-11-02        1  2779891.62
# 2   24901402  2780855.44  289574.96  2011-10-28        1  2780855.44
# 3  24901402A  2780821.30  289552.24  2011-10-28        1  2780821.30
# 4  24901402B  2780824.40  289551.25  2011-10-28        1  2780824.40
#
#          LON         lat        lon
# 0  290155.40  2777271.63  290155.40
# 1  288359.56  2779891.62  288359.56
# 2  289574.96  2780855.44  289574.96
# 3  289552.24  2780821.30  289552.24
# 4  289551.25  2780824.40  289551.25

# %%
twd97.towgs84(290155.40,2777271.63 )
# Out:
# (25.103237710994744, 121.39814582796106)

# %%
lats = np.ones(len(df))
lons = np.ones(len(df))

# %%
for i in df.index:
    if df.loc[i].LON > 125 and df.loc[i].LAT > 26:
        (lats[i], lons[i]) = twd97.towgs84(df.loc[i].LON, df.loc[i].LAT)
    else:
        (lats[i], lons[i]) = (df.loc[i].LON, df.loc[i].LAT)

# %%
df.lat = lats
df.lon = lons

# %%
len(df.lon.unique())
# Out:
# 9821

# %%
df
# Out:
#         Tube ID     LAT (Y)    LON (X)        Date  IS RIFA         LAT  \
# 0      24901723  2777271.63  290155.40  2011-08-18        1  2777271.63
# 1      24900702  2779891.62  288359.56  2011-11-02        1  2779891.62
# 2      24901402  2780855.44  289574.96  2011-10-28        1  2780855.44
# 3     24901402A  2780821.30  289552.24  2011-10-28        1  2780821.30
# 4     24901402B  2780824.40  289551.25  2011-10-28        1  2780824.40
# ...         ...         ...        ...         ...      ...         ...
# 9835   23903301  2761935.22  288033.30  2011-06-08        0  2761935.22
# 9836   23903302  2761863.13  288360.16  2011-06-08        0  2761863.13
# 9837   23903303  2761882.39  288505.02  2011-06-08        0  2761882.39
# 9838   23903307  2761703.32  288068.57  2011-06-08        0  2761703.32
# 9839   23903313  2761560.76  288099.14  2011-06-08        0  2761560.76
#
#             LON        lat         lon
# 0     290155.40  25.103238  121.398146
# 1     288359.56  25.126938  121.380413
# 2     289574.96  25.135608  121.392494
# 3     289552.24  25.135300  121.392268
# 4     289551.25  25.135328  121.392258
# ...         ...        ...         ...
# 9835  288033.30  24.964833  121.376682
# 9836  288360.16  24.964174  121.379917
# 9837  288505.02  24.964345  121.381353
# 9838  288068.57  24.962739  121.377025
# 9839  288099.14  24.961451  121.377324
#
# [9840 rows x 9 columns]

# %%
dfrifa = df[df['IS RIFA']==1]

# %%
dfrifa.reset_index()
# Out:
#      index    Tube ID     LAT (Y)    LON (X)        Date  IS RIFA         LAT  \
# 0        0   24901723  2777271.63  290155.40  2011-08-18        1  2777271.63
# 1        1   24900702  2779891.62  288359.56  2011-11-02        1  2779891.62
# 2        2   24901402  2780855.44  289574.96  2011-10-28        1  2780855.44
# 3        3  24901402A  2780821.30  289552.24  2011-10-28        1  2780821.30
# 4        4  24901402B  2780824.40  289551.25  2011-10-28        1  2780824.40
# ..     ...        ...         ...        ...         ...      ...         ...
# 342   9338   23902122  2759237.93  285096.66  2011-05-31        1  2759237.93
# 343   9339   23902413  2762453.10  285608.67  2011-06-01        1  2762453.10
# 344   9340   23902609  2760710.07  286130.88  2011-06-07        1  2760710.07
# 345   9341   23902709  2759636.30  286146.88  2011-06-07        1  2759636.30
# 346   9342   23903308  2761757.95  288318.29  2011-06-08        1  2761757.95
#
#            LON        lat         lon
# 0    290155.40  25.103238  121.398146
# 1    288359.56  25.126938  121.380413
# 2    289574.96  25.135608  121.392494
# 3    289552.24  25.135300  121.392268
# 4    289551.25  25.135328  121.392258
# ..         ...        ...         ...
# 342  285096.66  24.940552  121.347530
# 343  285608.67  24.969568  121.352682
# 344  286130.88  24.953819  121.357809
# 345  286146.88  24.944124  121.357939
# 346  288318.29  24.963226  121.379500
#
# [347 rows x 10 columns]

# %%
dfrifa.iloc[0]
# Out:
# Tube ID       24901723
# LAT (Y)    2.77727e+06
# LON (X)         290155
# Date        2011-08-18
# IS RIFA              1
# LAT        2.77727e+06
# LON             290155
# lat            25.1032
# lon            121.398
# Name: 0, dtype: object

# %%
geojson_file = {
"type": "FeatureCollection",
"features": []
};

# %%
for i in range(10):
    feat = dfrifa.iloc[i*10]
    unit = { "type": "Feature",
            "geometry": {
            "type": "Point",
            "coordinates": [feat.lat, feat.lon]
           },
          "properties": {
           "id": i+1,
           "name": feat['Tube ID'],
           "site": ""
            }
        }
    geojson_file['features'].append(unit)

# %%
geojson_file
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [25.103237710994744, 121.39814582796106]},
#    'properties': {'id': 1, 'name': '24901723', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [25.05894809179354, 121.4788596831123]},
#    'properties': {'id': 2, 'name': '(missing)', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [24.965789998808894, 121.41667647410208]},
#    'properties': {'id': 3, 'name': '23600427', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [24.993618296782874, 121.49087032733674]},
#    'properties': {'id': 4, 'name': '23501228', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [25.08724439488872, 121.44296116455904]},
#    'properties': {'id': 5, 'name': '24802816', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [24.976523091026145, 121.43355091535139]},
#    'properties': {'id': 6, 'name': '22000323C', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [24.976065193733962, 121.43413428621233]},
#    'properties': {'id': 7, 'name': '22000330B', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [25.07806900759949, 121.36638133342159]},
#    'properties': {'id': 8, 'name': '24404313', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [25.096093974307216, 121.34379747260792]},
#    'properties': {'id': 9, 'name': '24402514', 'site': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [25.118811175092397, 121.35190134996037]},
#    'properties': {'id': 10, 'name': '24402230', 'site': ''}}]}

# %%
with open('data.geojson', 'w') as fp:
    json.dump(geojson_file, fp, indent=4)

# %%
n = 2

# %%
import numpy as np
import matplotlib.pyplot as plt

#3*3 Gassian filter
x, y = np.mgrid[-n:n+1, -n:n+1]
gaussian_kernel = np.exp(-(x**2+y**2))

#Normalization
#gaussian_kernel = gaussian_kernel / gaussian_kernel.sum()

plt.imshow(gaussian_kernel, cmap=plt.get_cmap('jet'), interpolation='nearest')
plt.colorbar()
plt.show()

# %%
fgaussian = gaussian_kernel.ravel()

# %%
from math import radians, cos, sin, asin, sqrt
 
def haversine(lon1, lat1, lon2, lat2): # 经度1，纬度1，经度2，纬度2 （十进制度数）
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # 将十进制度数转化为弧度
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
 
    # haversine公式
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # 地球平均半径，单位为公里
    return c * r * 1000

# %%
haversine(df.lat[0], df.lon[0],df.lat[0]+0.001, df.lon[0] )
# Out:
# 57.930556324874814

# %%
def makeMatrix(lat, lon, steps, dist=0.001, flatten=False):
    lats = np.ones(((2*steps+1), (2*steps+1)))*lat
    lons = np.ones(((2*steps+1), (2*steps+1)))*lon
    #lats[n, n] = lat
    #lons[n, n] = lon
    
    for i in range(steps+1):
        for j in range(2*steps+1):
        
            lats[steps-i, j] = lat - dist * i
            lats[steps+i, j] = lat + dist * i
            lons[j, steps-i] = lon - dist * i
            lons[j, steps+i] = lon + dist * i
    if flatten:
        return lats.ravel(), lons.ravel()
    else:
        return lats, lons

# %%
lats, lons = makeMatrix(df.lat[0], df.lon[0], 2)

# %%
lats.ravel().shape
# Out:
# (25,)

# %%
plt.imshow(lats, cmap=plt.get_cmap('jet'), interpolation='nearest')
#plt.imshow(lons, cmap=plt.get_cmap('jet'), interpolation='nearest')
plt.colorbar()
plt.show()

# %%
total_n = (2*n+1)**2
lats = np.ones(len(df)*total_n)
lons = np.ones(len(df)*total_n)
values = np.ones(len(df)*total_n)

# %%
for i in range(len(df)):
    lat = df.loc[i].lat
    lon = df.loc[i].lon
    latm, lonm = makeMatrix(lat, lon, n, dist=0.001, flatten=True)
    lats[i*total_n:(i+1)*total_n] = latm
    lons[i*total_n:(i+1)*total_n] = lonm
    values[i*total_n:(i+1)*total_n] = fgaussian

# %%
len(np.unique(lats))
# Out:
# 49105

# %%
len(lats)
# Out:
# 246000

# %%
gaudict = {'glat':(lats*1e4//1)*1e-4, 'glon':(lons*1e4//1)*1e-4, 'value':values}

# %%
gaudf = pd.DataFrame(gaudict)

# %%
gaudf.value
# Out:
# 0         0.000335
# 1         0.006738
# 2         0.018316
# 3         0.006738
# 4         0.000335
#             ...
# 245995    0.000335
# 245996    0.006738
# 245997    0.018316
# 245998    0.006738
# 245999    0.000335
# Name: value, Length: 246000, dtype: float64

# %%
gbygaudf = gaudf.groupby(['glat', 'glon'], as_index=False)['value'].sum()

# %%
import os
os.environ['PROJ_LIB'] = '/home/tsai/anaconda3/envs/RIFA/share/proj'
from mpl_toolkits.basemap import Basemap

# %%
"""
bmap = Basemap(projection='merc', 
                              resolution='i' , fix_aspect=True,
                              llcrnrlon=119.0 , llcrnrlat=21.8,
                              urcrnrlon=122.05 , urcrnrlat=25.4,
                              lat_ts =20)
"""
plt.figure(figsize=(30, 30))
bmap = Basemap(projection='merc', 
                              resolution='i' , fix_aspect=True,
                              llcrnrlon=121.0 , llcrnrlat=24.5,
                              urcrnrlon=122.0 , urcrnrlat=25.4,
                              lat_ts =20)
bmap.readshapefile('./Data/COUNTY_MOI_1081121', name='COUNTYID' , linewidth=0.25 , drawbounds=True)
#海岸線的寬度
bmap.drawcoastlines(linewidth=1)

#儲存map , dpi=100表示存成800*600
#plt.savefig('practice_map' , dpi=100)

#畫緯度線23.5和25,labels標示出座標度數,fontsize文字大小
bmap.drawparallels(np.arange(23.5 , 25) , labels=[1,0,0,0] , fontsize=10)

#畫經度線120和122,labels標示出座標度數,fontsize文字大小
bmap.drawmeridians(np.arange(120,122),labels=[0,0,0,1],fontsize=10)

#map 底色backgroubd-color
#bmap.drawmapboundary(fill_color='#85C1E9')
#bmap.drawlsmask(land_color='coral',ocean_color='#85C1E9',lakes=True)
#取一個title
plt.title('Practice')

#設定XY說明label , xy範圍0~1(預設是中間0.5)
plt.xlabel('lon' , fontsize=12 , x=1)
plt.ylabel('lat' , fontsize=12 , y=1)
#plt.figure(figsize=(10, 20))

#lon, lat = bmap(list(df.lon), list(df.lat)) # lon, lat為給定的經緯度，可以使單個的，也可以是列表
lon, lat = bmap(list(gbygaudf.glon), list(gbygaudf.glat)) # lon, lat為給定的經緯度，可以使單個的，也可以是列表
#values_ = values[:1000]
#bmap.plot(lon, lat, 'bo')         # 標註出所在的點，s為點的大小，還可以選擇點的性狀和顏色等屬性
#lonn, latt = np.meshgrid(np.array(lon).astype(np.float16), np.array(lat).astype(np.float16))
#bmap.contourf(np.array(lon), np.array(lat), values_)



#讀取shapefile

bmap.scatter(lon, lat, c = (np.log(gbygaudf.value) - np.log(gbygaudf.value).min()+1).astype(int), s=(np.log2(gbygaudf.value) - np.log2(gbygaudf.value).min()+1)/10, alpha=0.3, marker='o', cmap='jet')
plt.savefig("map.png", dpi=300)
plt.show
# Out:
# /home/tsai/.local/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   del sys.path[0]
# /home/tsai/.local/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
((np.log2(gbygaudf.value) - np.log2(gbygaudf.value).min()+1)//10).max()
# Out:
# 1.0

# %%
((np.log2(gbygaudf.value) - np.log2(gbygaudf.value).min()+1)/10).max()
# Out:
# 1.3785155956198598

# %%
(np.log(gbygaudf.value - np.log(gbygaudf.value).min()+1)).astype(int).min()
# Out:
# 2

# %%
(np.log(gbygaudf.value)+9).min()
# Out:
# 1.0

# %%
gbygaudf.value.min()
# Out:
# 0.00033546262790251185

# %%
np.log2(gbygaudf.value).max()
# Out:
# 1.2435956290868926

# %%
np.log2(gbygaudf.value).min()
# Out:
# -11.541560327111707

# %%
len(gbygaudf.values)
# Out:
# 236684

# %%
(np.log(gbygaudf.values)+9).astype(int)
# Out:
# array([[12, 13,  1],
#        [12, 13,  4],
#        [12, 13,  5],
#        ...,
#        [12, 13,  5],
#        [12, 13,  4],
#        [12, 13,  1]])

# %%
gbygaudf.values
# Out:
# array([[2.48256000e+01, 1.21444200e+02, 3.35462628e-04],
#        [2.48256000e+01, 1.21445200e+02, 6.73794700e-03],
#        [2.48256000e+01, 1.21446200e+02, 1.83156389e-02],
